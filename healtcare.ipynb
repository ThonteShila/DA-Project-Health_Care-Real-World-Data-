# %%
import matplotlib as plt 
import numpy as np
import seaborn as sns
import plotly.express as px
import pandas as pd

# %% [markdown]
# #Reading Dataset

# %%
df=pd.read_csv(r"C:\Shila Data\DA-Project(Health_Care Real-World Data)\Healthcare_dataset.csv")

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            31-01-2024     Matthew Smith               Sons and Miller
# ...

# %% [markdown]
# #Data cleaning

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df["Name"].unique
# Out:
# <bound method Series.unique of 0            Bobby JacksOn
# 1             LesLie TErRy
# 2              DaNnY sMitH
# 3             andrEw waTtS
# 4            adrIENNE bEll
#                ...
# 55495    eLIZABeTH jaCkSOn
# 55496           KYle pEREz
# 55497         HEATher WaNG
# 55498       JENniFER JOneS
# 55499         jAMES GARCiA
# Name: Name, Length: 55500, dtype: object>

# %% [markdown]
# #checking null values

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# #checking duplicates

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498    False
# 55499    False
# Length: 55500, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 534

# %%
df.drop_duplicates()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            31-01-2024     Matthew Smith               Sons and Miller
# ...

# %%
df.head(5)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        31-01-2024
# 1   LesLie TErRy   62    Male         A+           Obesity        20-08-2019
# 2    DaNnY sMitH   76  Female         A-           Obesity        22-09-2022
# 3   andrEw waTtS   28  Female         O+          Diabetes        18-11-2020
# 4  adrIENNE bEll   43  Female        AB+            Cancer        19-09-2022
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df["Name"]
# Out:
# 0            Bobby JacksOn
# 1             LesLie TErRy
# 2              DaNnY sMitH
# 3             andrEw waTtS
# 4            adrIENNE bEll
#                ...
# 55495    eLIZABeTH jaCkSOn
# 55496           KYle pEREz
# 55497         HEATher WaNG
# 55498       JENniFER JOneS
# 55499         jAMES GARCiA
# Name: Name, Length: 55500, dtype: object

# %% [markdown]
# #Data validation

# %%
df["Name"]=df["Name"].str.title()

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            31-01-2024     Matthew Smith               Sons and Miller
# ...

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30    Male         B-            Cancer        31-01-2024
# 1   Leslie Terry   62    Male         A+           Obesity        20-08-2019
# 2    Danny Smith   76  Female         A-           Obesity        22-09-2022
# 3   Andrew Watts   28  Female         O+          Diabetes        18-11-2020
# 4  Adrienne Bell   43  Female        AB+            Cancer        19-09-2022
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224655    202.000000
# 50%       52.000000    25538.069380    302.000000
# 75%       68.000000    37820.508432    401.000000
# max       89.000000    52764.276740    500.000000

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %% [markdown]
# #Changing Date datatype from object to date

# %%
df["Date of Admission"]
# Out:
# 0        31-01-2024
# 1        20-08-2019
# 2        22-09-2022
# 3        18-11-2020
# 4        19-09-2022
#             ...
# 55495    16-08-2020
# 55496    23-01-2020
# 55497    13-07-2020
# 55498    25-05-2019
# 55499    02-04-2024
# Name: Date of Admission, Length: 55500, dtype: object

# %%
df["Date of Admission"]=pd.to_datetime(df["Date of Admission"])
# Out:
# C:\Users\santo\AppData\Local\Temp\ipykernel_16512\3345540159.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Date of Admission"]=pd.to_datetime(df["Date of Admission"])

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore')

# %%
df.dtypes
# Out:
# Name                          object
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                    int64
# Admission Type                object
# Discharge Date                object
# Medication                    object
# Test Results                  object
# dtype: object

# %%
df["Discharge Date"]=pd.to_datetime(df["Discharge Date"],dayfirst=True)

# %%
df.dtypes
# Out:
# Name                          object
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                    int64
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# dtype: object

# %%
df.head(2)
# Out:
#             Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30   Male         B-            Cancer        2024-01-31
# 1   Leslie Terry   62   Male         A+           Obesity        2019-08-20
#
#             Doctor         Hospital Insurance Provider  Billing Amount  \
# 0    Matthew Smith  Sons and Miller         Blue Cross     18856.28131
# 1  Samantha Davies          Kim Inc           Medicare     33643.32729
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     2024-02-02  Paracetamol        Normal
# 1          265      Emergency     2019-08-26    Ibuprofen  Inconclusive

# %% [markdown]
# #Feature Engineering
# 1-No of days patient leave in hospital

# %%
df["Patient_leave_in_hospital"]=df["Discharge Date"]-df["Date of Admission"]

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.dtypes
# Out:
# Name                                  object
# Age                                    int64
# Gender                                object
# Blood Type                            object
# Medical Condition                     object
# Date of Admission             datetime64[ns]
# Doctor                                object
# Hospital                              object
# Insurance Provider                    object
# Billing Amount                       float64
# Room Number                            int64
# Admission Type                        object
# Discharge Date                datetime64[ns]
# Medication                            object
# Test Results                          object
# Patient_leave_in_hospital    timedelta64[ns]
# dtype: object

# %% [markdown]
# #Data

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %% [markdown]
# #Finding how is ratio of male and female with different category

# %%
leavedays_codition=df.groupby("Medical Condition")["Patient_leave_in_hospital"].count()
leavedays_codition
# Out:
# Medical Condition
# Arthritis       9308
# Asthma          9185
# Cancer          9227
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Name: Patient_leave_in_hospital, dtype: int64

# %%
leavedays_codition.plot(kind='bar',x=df["Medical Condition"],y=df["Patient_leave_in_hospital"])
# Out:
# <Axes: xlabel='Medical Condition'>

# %% [markdown]
# Insight-In above graph no of days patient need to leave in hospital are almost similar for both gender male and female.

# %%
from matplotlib import figure


df.groupby("Medical Condition")["Billing Amount"].plot(kind='hist',xlabel=df["Medical Condition"],
                                                       y=df["Billing Amount"])
# Out:
# Medical Condition
# Arthritis       Axes(0.125,0.11;0.775x0.77)
# Asthma          Axes(0.125,0.11;0.775x0.77)
# Cancer          Axes(0.125,0.11;0.775x0.77)
# Diabetes        Axes(0.125,0.11;0.775x0.77)
# Hypertension    Axes(0.125,0.11;0.775x0.77)
# Obesity         Axes(0.125,0.11;0.775x0.77)
# Name: Billing Amount, dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results', 'Patient_leave_in_hospital'],
#       dtype='object')

# %%
sns.barplot(x=df["Medical Condition"],y=df["Billing Amount"])
# Out:
# <Axes: xlabel='Medical Condition', ylabel='Billing Amount'>

# %%
sns.countplot(x=df["Medical Condition"],hue=df["Gender"])
# Out:
# <Axes: xlabel='Medical Condition', ylabel='count'>

# %%
sns.countplot(x=df["Medical Condition"],hue=df["Medication"])
# Out:
# <Axes: xlabel='Medical Condition', ylabel='count'>

# %%
df.groupby("Medical Conditi"on)["Billing Amount"].sum().plot(kind='pie',autopct="%0.2f%%")
# Out:
#   Cell In[37], line 1
#     df.groupby("Medical Conditi"on)["Billing Amount"].sum().plot(kind='pie',autopct="%0.2f%%")
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.groupby("Admission Type")["Billing Amount"].mean()
# Out:
# Admission Type
# Elective     25602.226311
# Emergency    25497.397157
# Urgent       25517.364497
# Name: Billing Amount, dtype: float64

# %%
data=df.groupby("Medical Condition")["Patient_leave_in_hospital"].value_counts()

# %%
data
# Out:
# Medical Condition  Patient_leave_in_hospital
# Arthritis          14 days                      356
#                    19 days                      356
#                    13 days                      340
#                    9 days                       338
#                    24 days                      330
#                                                ...
# Obesity            3 days                       282
#                    29 days                      279
#                    12 days                      278
#                    19 days                      276
#                    16 days                      269
# Name: count, Length: 180, dtype: int64

# %%
sns.countplot(x=df["Blood Type"],hue=df["Test Results"])
# Out:
# <Axes: xlabel='Blood Type', ylabel='count'>

# %% [markdown]
# #Insight-in above graph all blood type have almost normal test result.

# %%
df.head(2)
# Out:
#             Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30   Male         B-            Cancer        2024-01-31
# 1   Leslie Terry   62   Male         A+           Obesity        2019-08-20
#
#             Doctor         Hospital Insurance Provider  Billing Amount  \
# 0    Matthew Smith  Sons and Miller         Blue Cross     18856.28131
# 1  Samantha Davies          Kim Inc           Medicare     33643.32729
#
#    Room Number Admission Type Discharge Date   Medication  Test Results  \
# 0          328         Urgent     2024-02-02  Paracetamol        Normal
# 1          265      Emergency     2019-08-26    Ibuprofen  Inconclusive
#
#   Patient_leave_in_hospital
# 0                    2 days
# 1                    6 days

# %%
age_bill_df=df.groupby("Age")["Billing Amount"].mean()

# %%
age_bill_df=pd.DataFrame(age_bill_df)
age_bill_df
# Out:
#      Billing Amount
# Age
# 13     29017.383294
# 14     31664.686881
# 15     30000.734363
# 16     25865.485814
# 17     27202.884255
# ..              ...
# 85     25632.640547
# 86     27487.952331
# 87     24680.310047
# 88     21985.572250
# 89     18012.058731
#
# [77 rows x 1 columns]

# %%
sns.histplot(age_bill_df,x="Age",y="Billing Amount")
# Out:
# <Axes: xlabel='Age', ylabel='Billing Amount'>

# %% [markdown]
# #Above graph represents according to age group how billing amount varies.

# %%
df["Insurance needed"]=df["Billing Amount"].apply(lambda x:"Insurance required" if (x>25000) else "Not Required")

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df["Insurance needed"].unique
# Out:
# <bound method Series.unique of 0              Not Required
# 1        Insurance required
# 2        Insurance required
# 3        Insurance required
# 4              Not Required
#                 ...
# 55495          Not Required
# 55496    Insurance required
# 55497    Insurance required
# 55498    Insurance required
# 55499          Not Required
# Name: Insurance needed, Length: 55500, dtype: object>

# %%
admission_type_by_date=df.groupby("Date of Admission")["Admission Type"].count()

# %%
admission_type_by_date=pd.DataFrame(admission_type_by_date)
admission_type_by_date
# Out:
#                    Admission Type
# Date of Admission
# 2019-05-08                     27
# 2019-05-09                     38
# 2019-05-10                     17
# 2019-05-11                     25
# 2019-05-12                     36
# ...                           ...
# 2024-05-03                     31
# 2024-05-04                     24
# 2024-05-05                     26
# 2024-05-06                     33
# 2024-05-07                     33
#
# [1827 rows x 1 columns]

# %%
sns.histplot(df,x="Date of Admission",hue="Admission Type")
# Out:
# <Axes: xlabel='Date of Admission', ylabel='Count'>

# %% [markdown]
# #This graph represent on each date count for each admission type.

# %%
def consult(result):
    if result=="Normal":
        return "Not necessary" 
    elif result=="Inconclusive":
        return  "Meet Dr every 3 month"
    else:
        "Must visit Dr"

df["Action Needed"]=df["Test Results"].apply(consult)

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df["Admission Type"].value_counts()
# Out:
# Admission Type
# Elective     18655
# Urgent       18576
# Emergency    18269
# Name: count, dtype: int64

# %%
def cases(result):
    if result=="Elective":
        return "not immediately"
    elif result=="Urgent":
        return "require attention"
    else: 
        return " Immediately"
df["Case_type"]=df["Admission Type"].apply(cases)
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...
